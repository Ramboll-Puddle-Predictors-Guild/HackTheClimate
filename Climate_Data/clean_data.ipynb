# %%
import polars as pl

data = pl.read_csv("query_result_10km2.csv").lazy()


print(data.collect())

# data.with_columns(pl.col(""))
# Out:
# shape: (11_537, 6)
# ┌───────────┬──────────┬─────────────────┬───────────┬───────────────┬───────────────┐
# │ xlat      ┆ xlong    ┆ qrain_avg_150.0 ┆ rainc_avg ┆ rho_avg_150.0 ┆ wsp_avg_150.0 │
# │ ---       ┆ ---      ┆ ---             ┆ ---       ┆ ---           ┆ ---           │
# │ f64       ┆ f64      ┆ f64             ┆ f64       ┆ f64           ┆ f64           │
# ╞═══════════╪══════════╪═════════════════╪═══════════╪═══════════════╪═══════════════╡
# │ 52.955715 ┆ 4.881531 ┆ 0.000005        ┆ 0.0       ┆ 1.222819      ┆ 9.394839      │
# │ 56.828506 ┆ 5.070953 ┆ 0.000006        ┆ 0.0       ┆ 1.226711      ┆ 10.827232     │
# │ 53.555893 ┆ 4.789795 ┆ 0.000005        ┆ 0.0       ┆ 1.223429      ┆ 10.128097     │
# │ 53.922485 ┆ 5.593994 ┆ 0.000005        ┆ 0.0       ┆ 1.223911      ┆ 10.195348     │
# │ 55.466118 ┆ 6.412384 ┆ 0.000005        ┆ 0.0       ┆ 1.225269      ┆ 10.52217      │
# │ …         ┆ …        ┆ …               ┆ …         ┆ …             ┆ …             │
# ...
